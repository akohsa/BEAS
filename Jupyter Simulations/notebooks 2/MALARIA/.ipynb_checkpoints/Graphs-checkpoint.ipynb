# %%
# importing the required module
import matplotlib.pyplot as plt
import numpy as np
from scipy.interpolate import make_interp_spline
  
# x axis values
x = np.array([0.05, 0.1, 0.15, 0.2])
# corresponding y axis values
y = np.array([85.84, 59.92, 50.41, 50.07])
y2 = np.array([96.39, 94.7, 94.16, 91.68])

# Dataset

xy = make_interp_spline(x, y)
xy2 = make_interp_spline(x, y2)
 
# Returns evenly spaced numbers
# over a specified interval.
x = np.linspace(x.min(), x.max(), 100)
y = xy(x)
y2 = xy2(x)

  
# plotting the points 
plt.plot(x, y, label='Malaria Cell Image', color='red')
plt.plot(x, y2, label='MNIST', color='blue')
  
# naming the x axis
plt.xlabel('Gaussiuan Noise Standard Deviation')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
  
# giving a title to my graph
plt.title('Gaussian Noise Std Dev vs Global Accuracy')
# plt.ylim([48, 100])
plt.legend()
  
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
  
# x axis values
x = np.sort(np.array([0.90, 0.80, 0.70, 0.60]))
# corresponding y axis values
y =  np.sort(np.array([95.02,94.55,94.,93.97]))
y2 = np.sort(np.array([96.38, 96.63, 96.17, 96.16]))

xy = make_interp_spline(x, y)
xy2 = make_interp_spline(x, y2)
 
# Returns evenly spaced numbers
# over a specified interval.
x = np.linspace(x.min(), x.max(), 500)
y = xy(x)
y2 = xy2(x)

# plt.gca().invert_xaxis()
# plotting the points 
plt.plot(x, y, label='Malaria Cell Image', color='red')
plt.plot(x, y2, label='MNIST', color='blue')
  
# naming the x axis
plt.xlabel('Gradient Clip Norm')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# giving a title to my graph
plt.title('Gradient Clip Norm vs Global Accuracy')
plt.legend()
            
  
# function to show the plot
plt.show()

# %%
# importing the required module
import matplotlib.pyplot as plt
  
# x axis values
x = np.sort(np.array([0.90, 0.75, 0.60, 0.45]))
# corresponding y axis values
y = np.array([93.39, 93.97, 92.95, 92.17])
y2 = np.array([96.67, 96.46, 96.11, 94.98])
            
xy = make_interp_spline(x, y)
xy2 = make_interp_spline(x, y2)
 
# Returns evenly spaced numbers
# over a specified interval.
x = np.linspace(x.min(), x.max(), 500)
y = xy(x)
y2 = xy2(x)

  
# plotting the points 
plt.plot(x, y, label='Malaria Cell Image', color='red')
plt.plot(x, y2, label='MNIST', color='blue')
  
# naming the x axis
plt.xlabel('Gradient Pruning Sparcity')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([48, 100])
# giving a title to my graph
plt.title('Gradient Pruning Sparcity vs Global Accuracy')
plt.legend()
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()

# %%
## Malaria

# importing the required module
import matplotlib.pyplot as plt

reg = np.array([0.5012704133987427, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5270417332649231, 0.5858439207077026, 0.6333938241004944, 0.6421052813529968, 0.5803992748260498, 0.688566267490387, 0.686388373374939, 0.7157894968986511, 0.7059891223907471, 0.7023593187332153, 0.7274047136306763, 0.7411978244781494, 0.7731397747993469, 0.7927404642105103, 0.7756806015968323, 0.8228675127029419, 0.836660623550415, 0.8784028887748718, 0.8820326924324036, 0.882758617401123, 0.8838475346565247, 0.9096188545227051, 0.9049001932144165, 0.8980036377906799, 0.9143375754356384, 0.9085299372673035, 0.9255898594856262, 0.9081669449806213, 0.9223230481147766, 0.9139745831489563, 0.8715063333511353, 0.9088929295539856, 0.8990925550460815, 0.9099818468093872, 0.9052631855010986, 0.9194192290306091, 0.9263157844543457, 0.9284936189651489, 0.9237749576568604, 0.8972776532173157, 0.9194192290306091, 0.9274047017097473])
cent = np.array([0.9553 for i in range(len(reg))])
noise_p05 = np.array([0.5012704133987427, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0
xnoise_p20 = make_interp_spline(x, noise_p20)

x = np.linspace(x.min(), x.max(), 500)
  
# plotting the points 
plt.plot(x, xcent(x), label='Centralized Accuracy', color='red')
plt.plot(x, xreg(x), label='BEAS (No Noise)', color='black')
plt.plot(x, xnoise_p05(x), label='BEAS (Noise - 0.05 STD DEV)', color='blue')
plt.plot(x, xnoise_p10(x), label='BEAS (Noise - 0.10 STD DEV)', color='green')
plt.plot(x, xnoise_p15(x), label='BEAS (Noise - 0.15 STD DEV)', color='purple')
plt.plot(x, xnoise_p20(x), label='BEAS (Noise - 0.20 STD DEV)', color='orange')
  
# naming the x axis
plt.xlabel('Global Training Round')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([0.3, 1])
# giving a title to my graph
plt.title('Dataset: Malaria Cell Image')
plt.legend(fontsize=7.5, loc=2)
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()

# %%
## Malaria

# importing the required module
import matplotlib.pyplot as plt

reg = np.array([0.5012704133987427, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5270417332649231, 0.5858439207077026, 0.6333938241004944, 0.6421052813529968, 0.5803992748260498, 0.688566267490387, 0.686388373374939, 0.7157894968986511, 0.7059891223907471, 0.7023593187332153, 0.7274047136306763, 0.7411978244781494, 0.7731397747993469, 0.7927404642105103, 0.7756806015968323, 0.8228675127029419, 0.836660623550415, 0.8784028887748718, 0.8820326924324036, 0.882758617401123, 0.8838475346565247, 0.9096188545227051, 0.9049001932144165, 0.8980036377906799, 0.9143375754356384, 0.9085299372673035, 0.9255898594856262, 0.9081669449806213, 0.9223230481147766, 0.9139745831489563, 0.8715063333511353, 0.9088929295539856, 0.8990925550460815, 0.9099818468093872, 0.9052631855010986, 0.9194192290306091, 0.9263157844543457, 0.9284936189651489, 0.9237749576568604, 0.8972776532173157, 0.9194192290306091, 0.9274047017097473])
cent = np.array([0.9553 for i in range(len(reg))])
c9 = np.array([0.5012704133987427, 0.4987295866012573, 0.5484573245048523, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5666061639785767, 0.5437386631965637, 0.6457350254058838, 0.6065335869789124, 0.663520872592926, 0.6250453591346741, 0.6882032752037048, 0.6878402829170227, 0.7168784141540527, 0.723048985004425, 0.7176043391227722, 0.7103448510169983, 0.723048985004425, 0.7237749695777893, 0.7684210538864136, 0.7531760334968567, 0.7716878652572632, 0.7909255623817444, 0.7985481023788452, 0.8199636936187744, 0.834482729434967, 0.8646097779273987, 0.8798547983169556, 0.8958257436752319, 0.8998185396194458, 0.911433756351471, 0.9255898594856262, 0.9335753321647644, 0.934664249420166, 0.9364791512489319, 0.9303085207939148, 0.9411978125572205, 0.9313974380493164, 0.9470054507255554, 0.9372050762176514, 0.940471887588501, 0.934664249420166, 0.9408348202705383, 0.9324864149093628, 0.940471887588501, 0.9422867298126221, 0.9303085207939148, 0.950272262096405])
c8 = np.array([0.5012704133987427, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.6794918179512024, 0.6994555592536926, 0.6983665823936462, 0.7074410319328308, 0.7219600677490234, 0.7263157963752747, 0.7415608167648315, 0.7491832971572876, 0.7607985734939575, 0.7793103456497192, 0.7796733379364014, 0.7800362706184387, 0.8145190477371216, 0.8275862336158752, 0.836660623550415, 0.8490018248558044, 0.8711434006690979, 0.8773139715194702, 0.8794918060302734, 0.8947368264198303, 0.9096188545227051, 0.9147005677223206, 0.9281306862831116, 0.9324864149093628, 0.9201452136039734, 0.9241379499435425, 0.9284936189651489, 0.9284936189651489, 0.938293993473053, 0.934664249420166, 0.9415608048439026, 0.9393829107284546, 0.9390199780464172, 0.9426497220993042, 0.9339382648468018, 0.9390199780464172, 0.9386569857597351, 0.9335753321647644, 0.9422867298126221, 0.9426497220993042, 0.9335753321647644, 0.9455535411834717])
c7 = np.array([0.5012704133987427, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5023593306541443, 0.6312159895896912, 0.6323049068450928, 0.7110707759857178, 0.7070780396461487, 0.7063521146774292, 0.7321234345436096, 0.7270417213439941, 0.7295825481414795, 0.7589836716651917, 0.7629764080047607, 0.7705988883972168, 0.7785844206809998, 0.790562629699707, 0.8068965673446655, 0.8225045204162598, 0.8471869230270386, 0.8515426516532898, 0.8725953102111816, 0.888566255569458, 0.9009074568748474, 0.9016333818435669, 0.9088929295539856, 0.9241379499435425, 0.9306715130805969, 0.924863874912262, 0.9339382648468018, 0.9303085207939148, 0.9237749576568604, 0.9415608048439026, 0.9470054507255554, 0.9372050762176514, 0.9350272417068481, 0.934664249420166, 0.9441016316413879, 0.9415608048439026, 0.9332123398780823, 0.9393829107284546, 0.9426497220993042, 0.931034505367279, 0.934664249420166, 0.9335753321647644, 0.9252268671989441, 0.9470054507255554])
c6 = np.array([0.5012704133987427, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.49909254908561707, 0.5502722263336182, 0.5698729753494263, 0.6362976431846619, 0.5357531905174255, 0.5586206912994385, 0.6548094153404236, 0.6442831158638, 0.6987295746803284, 0.6849364638328552, 0.6551724076271057, 0.7088929414749146, 0.7306715250015259, 0.7321234345436096, 0.7313974499702454, 0.75789475440979, 0.7441016435623169, 0.7622504830360413, 0.771324872970581, 0.7891107201576233, 0.80181485414505, 0.8090744018554688, 0.8261343240737915, 0.8410163521766663, 0.8475499153137207, 0.8450090885162354, 0.8882032632827759, 0.9023593664169312, 0.91542649269104, 0.905626118183136, 0.9230489730834961, 0.9147005677223206, 0.9121596813201904, 0.9234119653701782, 0.9281306862831116, 0.9201452136039734, 0.9335753321647644, 0.9295825958251953, 0.9317604303359985, 0.9321234226226807, 0.9179673194885254, 0.9397459030151367])

x = np.array([i for i in range(len(reg))])

xreg = make_interp_spline(x, reg)
xcent = make_interp_spline(x, cent)
xc9 = make_interp_spline(x, c9)
xc8 = make_interp_spline(x, c8)
xc7 = make_interp_spline(x, c7)
xc6 = make_interp_spline(x, c6)

x = np.linspace(x.min(), x.max(), 500)
  
# plotting the points 
plt.plot(x, xcent(x), label='Centralized Accuracy', color='red')
plt.plot(x, xreg(x), label='BEAS (No Clip)', color='black')
plt.plot(x, xc9(x), label='BEAS (Clip Norm - 0.9)', color='blue')
plt.plot(x, xc8(x), label='BEAS (Clip Norm - 0.8)', color='green')
plt.plot(x, xc7(x), label='BEAS (Clip Norm - 0.7)', color='purple')
plt.plot(x, xc6(x), label='BEAS (Clip Norm - 0.6)', color='orange')
  
# naming the x axis
plt.xlabel('Global Training Round')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([0.3, 1])
# giving a title to my graph
plt.title('Dataset: Malaria Cell Image')
plt.legend(fontsize=7.5, loc=2)
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()

# %%
## Malaria

# importing the required module
import matplotlib.pyplot as plt

reg = np.array([0.5012704133987427, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.
 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5811251997947693, 0.5843920111656189, 0.6101633310317993, 0.6511796712875366, 0.667150616645813, 0.607622504234314, 0.6196007132530212, 0.669328510761261, 0.6907441020011902, 0.7139745950698853, 0.6736842393875122, 0.7136116027832031, 0.7088929414749146, 0.7205081582069397, 0.7484573721885681, 0.7528130412101746, 0.771324872970581, 0.8007259368896484, 0.8156079649925232, 0.8384755253791809, 0.8254083395004272, 0.8646097779273987, 0.8776769638061523, 0.8882032632827759, 0.8776769638061523, 0.8856624364852905, 0.8871143460273743, 0.8918330073356628, 0.8784028887748718, 0.9150635004043579, 0.9165154099464417, 0.9194192290306091, 0.9117967486381531, 0.9143375754356384, 0.9179673194885254, 0.9215971231460571, 0.9208711385726929, 0.921234130859375, 0.9284936189651489, 0.92704176902771, 0.9292196035385132, 0.9313974380493164, 0.9041742086410522, 0.9295825958251953])
p45 = np.array([0.4987295866012573, 0.4987295866012573, 0.4987295866012573, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5012704133987427, 0.5945553779602051, 0.6515426635742188, 0.6079854965209961, 0.6823956370353699, 0.6675136089324951, 0.6664246916770935, 0.7041742205619812, 0.7495462894439697, 0.7495462894439697, 0.7803992629051208, 0.7811252474784851, 0.7880218029022217, 0.7898366451263428, 0.8261343240737915, 0.8119782209396362, 0.8638838529586792, 0.8624319434165955, 0.8845735192298889, 0.8896551728248596, 0.8878402709960938, 0.8849364519119263, 0.9096188545227051, 0.8896551728248596, 0.9088929295539856, 0.9121596813201904, 0.8976406455039978, 0.8874773383140564, 0.9150635004043579, 0.9139745831489563, 0.9147005677223206, 0.9081669449806213, 0.9117967486381531, 0.9157894849777222, 0.9085299372673035, 0.9143375754356384, 0.9107078313827515, 0.9161524772644043, 0.9110707640647888, 0.9328493475914001, 0.9230489730834961, 0.9117967486381531, 0.9217604303359985])

x = np.array([i for i in range(len(reg))])

xreg = make_interp_spline(x, reg)
xcent = make_interp_spline(x, cent)
xp9 = make_interp_spline(x, p9)
xp75 = make_interp_spline(x, p75)
xp6 = make_interp_spline(x, p6)
xp45 = make_interp_spline(x, p45)

x = np.linspace(x.min(), x.max(), 500)
  
# plotting the points 
plt.plot(x, xcent(x), label='Centralized Accuracy', color='red')
plt.plot(x, xreg(x), label='BEAS (No Pruning)', color='black')
plt.plot(x, xp9(x), label='BEAS (Sparcity - 90%)', color='blue')
plt.plot(x, xp75(x), label='BEAS (Sparcity - 75%)', color='green')
plt.plot(x, xp6(x), label='BEAS (Sparcity - 60%)', color='purple')
plt.plot(x, xp45(x), label='BEAS (Sparcity - 45%)', color='orange')
  
# naming the x axis
plt.xlabel('Global Training Round')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([0.3, 1])
# giving a title to my graph
plt.title('Dataset: Malaria Cell Image')
plt.legend(fontsize=7.5, loc=2)
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()

# %%
## MNIST

# importing the required module
import matplotlib.pyplot as plt

024795532, 0.9157999753952026, 0.9265000224113464, 0.9262999892234802, 0.932200014591217, 0.9358999729156494, 0.9311000108718872, 0.9380000233650208, 0.9294000267982483, 0.9391000270843506, 0.9386000037193298, 0.9449999928474426, 0.9433000087738037, 0.9478999972343445, 0.9470000267028809, 0.9449999928474426, 0.9524000287055969, 0.9501000046730042, 0.9496999979019165, 0.9416000247001648])
noise_p20 = np.array([0.19189999997615814, 0.11779999732971191, 0.3431999981403351, 0.11630000174045563, 0.1881999969482422, 0.2969000041484833, 0.4366999864578247, 0.5414999723434448, 0.588100016117096, 0.590399980545044, 0.6287000179290771, 0.6463000178337097, 0.6830000281333923, 0.7156999707221985, 0.7172999978065491, 0.7615000009536743, 0.7867000102996826, 0.7802000045776367, 0.7997999787330627, 0.8036999702453613, 0.8197000026702881, 0.795199990272522, 0.8091999888420105, 0.8450999855995178, 0.8461999893188477, 0.8568999767303467, 0.847100019454956, 0.8647000193595886, 0.8651000261306763, 0.8927000164985657, 0.8870000243186951, 0.8881999850273132, 0.8916000127792358, 0.8982999920845032, 0.9009000062942505, 0.8845000267028809, 0.9032999873161316, 0.9004999995231628, 0.9122999906539917, 0.9089999794960022, 0.9078999757766724, 0.9057000279426575, 0.916100025177002, 0.9144999980926514, 0.9168999791145325, 0.914900004863739, 0.9186000227928162])

x = np.array([i for i in range(len(reg))])

xreg = make_interp_spline(x, reg)
xcent = make_interp_spline(x, cent)
xnoise_p05 = make_interp_spline(x, noise_p05)
xnoise_p10 = make_interp_spline(x, noise_p10)
xnoise_p15 = make_interp_spline(x, noise_p15)
xnoise_p20 = make_interp_spline(x, noise_p20)

x = np.linspace(x.min(), x.max(), 500)
  
# plotting the points 
plt.plot(x, xcent(x), label='Centralized Accuracy', color='red')
plt.plot(x, xreg(x), label='BEAS (No Noise)', color='black')
plt.plot(x, xnoise_p05(x), label='BEAS (Noise - 0.05 STD DEV)', color='blue')
plt.plot(x, xnoise_p10(x), label='BEAS (Noise - 0.10 STD DEV)', color='green')
plt.plot(x, xnoise_p15(x), label='BEAS (Noise - 0.15 STD DEV)', color='purple')
plt.plot(x, xnoise_p20(x), label='BEAS (Noise - 0.20 STD DEV)', color='orange')
  
# naming the x axis
plt.xlabel('Global Training Round')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([0.3, 1])
# giving a title to my graph
plt.title('Dataset: MNIST')
plt.legend(fontsize=7.5, loc=2)
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()

# %%
## MNIST

# importing the required module
import matplotlib.pyplot as plt

reg = np.array([0.2215999960899353, 0.5286999940872192, 0.67330002784729, 0.7508000135421753, 0.78329998254776, 0.8327999711036682, 0.8468000292778015, 0.866599977016449, 0.8791000247001648, 0.8848000168800354, 0.9010999798774719, 0.9078999757766724, 0.9171000123023987, 0.9161999821662903, 0.9265999794006348, 0.9301999807357788, 0.928600013256073, 0.9330000281333923, 0.9370999932289124, 0.9391999840736389, 0.9401000142097473, 0.9452000260353088, 0.948199987411499, 0.9498999714851379, 0.9502000212669373, 0.9502999782562256, 0.9509
c6 = np.array([0.2078000009059906, 0.48510000109672546, 0.636900007724762, 0.745199978351593, 0.7752000093460083, 0.8206999897956848, 0.8463000059127808, 0.8525000214576721, 0.8679999709129333, 0.8773000240325928, 0.8736000061035156, 0.8863999843597412, 0.8985999822616577, 0.8985000252723694, 0.910099983215332, 0.9121000170707703, 0.9139000177383423, 0.9185000061988831, 0.9233999848365784, 0.9275000095367432, 0.9261000156402588, 0.9334999918937683, 0.9359999895095825, 0.9386000037193298, 0.9406999945640564, 0.9424999952316284, 0.944100022315979, 0.942300021648407, 0.9448000192642212, 0.9473000168800354, 0.9531000256538391, 0.9532999992370605, 0.9509999752044678, 0.9532999992370605, 0.9545999765396118, 0.9556999802589417, 0.9573000073432922, 0.9588000178337097, 0.9607999920845032, 0.9577999711036682, 0.9610000252723694, 0.9610000252723694, 0.9631999731063843, 0.9649999737739563, 0.9641000032424927, 0.9649999737739563, 0.9616000056266785])

x = np.array([i for i in range(len(reg))])

xreg = make_interp_spline(x, reg)
xcent = make_interp_spline(x, cent)
xc9 = make_interp_spline(x, c9)
xc8 = make_interp_spline(x, c8)
xc7 = make_interp_spline(x, c7)
xc6 = make_interp_spline(x, c6)

x = np.linspace(x.min(), x.max(), 500)
  
# plotting the points 
plt.plot(x, xcent(x), label='Centralized Accuracy', color='red')
plt.plot(x, xreg(x), label='BEAS (No Clip)', color='black')
plt.plot(x, xc9(x), label='BEAS (Clip Norm - 0.9)', color='blue')
plt.plot(x, xc8(x), label='BEAS (Clip Norm - 0.8)', color='green')
plt.plot(x, xc7(x), label='BEAS (Clip Norm - 0.7)', color='purple')
plt.plot(x, xc6(x), label='BEAS (Clip Norm - 0.6)', color='orange')
  
# naming the x axis
plt.xlabel('Global Training Round')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([0.5, 1])
# giving a title to my graph
plt.title('Dataset: MNIST')
plt.legend(fontsize=7.5, loc=2)
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()

# %%
## MNIST

# importing the required module
import matplotlib.pyplot as plt

reg = np.array([0.2215999960899353, 0.5286999940872192, 0.67330002784729, 0.7508000135421753, 0.78329998254776, 0.8327999711036682, 0.8468000292778015, 0.866599977016449, 0.8791000247001648, 0.8848000168800354, 0.9010999798774719, 0.9078999757766724, 0.9171000123023987, 0.9161999821662903, 0.9265999794006348, 0.9301999807357788, 0.928600013256073, 0.9330000281333923, 0.9370999932289124, 0.9391999840736389, 0.9401000142097473, 0.9452000260353088, 0.948199987411499, 0.9498999714851379, 0.9502000212669373, 0.9502999782562256, 0.9509999752044678, 0.9527000188827515, 0.9524999856948853, 0.9537000060081482, 0.9563000202178955, 0.95660001039505, 0.9539999961853027, 0.9559000134468079, 0.9557999968528748, 0.9606000185012817, 0.9606999754905701, 0.9603999853134155, 0.9629999995231628, 0.9617000222206116, 0.9635000228881836, 0.9641000032424927, 0.9653000235557556, 0.9634000062942505, 0.964900016784668, 0.9634000062942505, 0.9616000056266785])
cent = np.array([0.9889 for i in range(len(reg))])
p9 = np.array([0.23800000548362732, 0.4839000105857849, 0.675000011920929, 0.7628999948501587, 0.801800012588501, 0.8417999744415283, 0.8482999801635742, 0.8623999953269958, 0.869700014591217, 0.88919997215271, 0.8891000151634216, 0.9039999842643738, 0.9153000116348267, 0.9107999801635742, 0.9218000173568726, 0.9254000186920166, 0.930899977684021, 0.9352999925613403, 0.939300000667572, 0.9419000148773193, 0.9408000111579895, 0.9466999769210815, 0.9480000138282776, 0.9503999948501587, 0.9531000256538391, 0.9534000158309937, 0.9555000066757202, 0.955299973487854, 0.9556000232696533, 0.955299973487854, 0.9581999778747559, 0.9606999754905701, 0.9593999981880188, 0.9625999927520752, 0.960099995136261, 0.9611999988555908, 0.9628999829292297, 0.9629999995231628, 0.9638000130653381, 0.9639999866485596, 0.9652000069618225, 0.9649999737739563, 0.9649999737739563, 0.9660000205039978, 0.968999981880188, 0.9670000076293945, 0.96670001745224])
p75 = np.array([0.18979999423027039, 0.4916999936103821, 0.6776000261306763, 0.7508999705314636, 0.7926999926567078, 0.8432000279426575, 0.8547000288963318, 0.8618000149726868, 0.8755999803543091, 0.8913999795913696, 0.8881999850273132, 0.9092000126838684, 0.9121999740600586, 0.9140999913215637, 0.9204000234603882, 0.925599992275238, 0.9344000220298767, 0.9373000264167786, 0.942799985408783, 0.9441999793052673, 0.9391999840736389, 0.9519000053405762, 0.9528999924659729, 0.9539999961853027, 0.9552000164985657, 0.9553999900817871, 0.9552000164985657, 0.9577999711036682, 0.954200029373169, 0.9570000171661377, 0.9603999853134155, 0.9605000019073486, 0.9603000283241272, 0.9623000025749207, 0.9621000289916992, 0.9629999995231628, 0.963100016117096, 0.9625999927520752, 0.9660000205039978, 0.9664999842643738, 0.9672999978065491, 0.965499997138977, 0.9674000144004822, 0.9664999842643738, 0.9675999879837036, 0.965499997138977, 0.9646000266075134])
# p6 = np.array()
# p45 = np.array()

x = np.array([i for i in range(len(reg))])

xreg = make_interp_spline(x, reg)
xcent = make_interp_spline(x, cent)
xp9 = make_interp_spline(x, p9)
xp75 = make_interp_spline(x, p75)
# xp6 = make_interp_spline(x, p6)
# xp45 = make_interp_spline(x, p45)

x = np.linspace(x.min(), x.max(), 500)
  
# plotting the points 
plt.plot(x, xcent(x), label='Centralized Accuracy', color='red')
plt.plot(x, xreg(x), label='BEAS (No Pruning)', color='black')
plt.plot(x, xp9(x), label='BEAS (Sparcity - 90%)', color='blue')
plt.plot(x, xp75(x), label='BEAS (Sparcity - 75%)', color='green')
# plt.plot(x, xp6(x), label='BEAS (Sparcity - 60%)', color='purple')
# plt.plot(x, xp45(x), label='BEAS (Sparcity - 45%)', color='orange')
  
# naming the x axis
plt.xlabel('Global Training Round')
# naming the y axis
plt.ylabel('BEAS Global Accuracy')
# plt.ylim([0.3, 1])
# giving a title to my graph
plt.title('Dataset: MNIST')
plt.legend(fontsize=7.5, loc=2)
# plt.gca().invert_xaxis()

# function to show the plot
plt.show()
